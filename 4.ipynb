# %%
# آموزش مدل به مدت 50 دوره (epoch) و بررسی دقت روی داده‌های اعتبارسنجی
history = model.fit(x_train, y_train,
                    epochs=50,
                    validation_data=(x_val, y_val),
                    verbose=1)

# ارزیابی مدل روی داده‌های تست نهایی
test_loss, test_acc = model.evaluate(x_test_default, y_test_cat, verbose=0)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# Epoch 1/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.1891 - loss: 2.1570 - val_accuracy: 0.2788 - val_loss: 1.9616
# Epoch 2/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.3004 - loss: 1.9155 - val_accuracy: 0.3221 - val_loss: 1.8676
# Epoch 3/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.3291 - loss: 1.8558 - val_accuracy: 0.3429 - val_loss: 1.8181
# Epoch 4/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.3447 - loss: 1.8109 - val_accuracy: 0.3517 - val_loss: 1.7779
# Epoch 5/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.3615 - loss: 1.7676 - val_accuracy: 0.3627 - val_loss: 1.7460
# Epoch 6/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.3742 - loss: 1.7355 - val_accuracy: 0.3729 - val_loss: 1.7231
# Epoch 7/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.3851 - loss: 1.7078 - val_accuracy: 0.3725 - val_loss: 1.7130
# Epoch 8/50
# ...
