# %%
# نرمال‌سازی پیکسل‌های تصاویر به بازه ۰ تا ۱ برای بهبود عملکرد مدل
x_train_full = x_train_full / 255.0
x_test_default = x_test_default / 255.0

# تبدیل برچسب‌ها به فرمت one-hot برای آموزش مدل‌های چندکلاسه
y_train_full_cat = keras.utils.to_categorical(y_train_full, 10)
y_test_cat = keras.utils.to_categorical(y_test_default, 10)

# تقسیم ۱۵٪ داده‌ها برای اعتبارسنجی (Validation) با استفاده از sklearn
x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full_cat, test_size=0.15, random_state=42
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # نرمال‌سازی پیکسل‌های تصاویر به بازه ۰ تا ۱ برای بهبود عملکرد مدل
# ----> 2 x_train_full = x_train_full / 255.0
#       3 x_test_default = x_test_default / 255.0
#       5 # تبدیل برچسب‌ها به فرمت one-hot برای آموزش مدل‌های چندکلاسه
#
# NameError: name 'x_train_full' is not defined
